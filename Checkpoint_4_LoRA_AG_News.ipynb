# %% [markdown]
# <a href="https://colab.research.google.com/github/Natalia-Marcela-Alvarez/Data-Science-III-AG-News/blob/main/Checkpoint_4_LoRA_AG_News.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Verificar la GPU

# %%
import torch

print("GPU disponible:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
else:
    print("No hay GPU disponible.")
# Out:
# GPU disponible: True
# GPU: Tesla T4

# %% [markdown]
# Instalar las librerías

# %%
# !pip install -q transformers datasets peft accelerate evaluate scikit-learn
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 3.9 MB/s eta 0:00:00

# %% [markdown]
# Importar las librerías

# %%
import torch
import numpy as np
import pandas as pd

from datasets import Dataset, DatasetDict
from transformers import (
    AutoTokenizer,
    AutoModelForSequenceClassification,
    TrainingArguments,
    Trainer
)

from peft import LoraConfig, TaskType, get_peft_model

from sklearn.metrics import accuracy_score, precision_recall_fscore_support

# %%
print("PyTorch:", torch.__version__)
print("GPU disponible:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# PyTorch: 2.11.0+cu128
# GPU disponible: True
# GPU: Tesla T4

# %% [markdown]
# Carga del dataset

# %%
import pandas as pd

train_df = pd.read_csv("/content/ag_news_train.csv")
test_df = pd.read_csv("/content/ag_news_test.csv")

print("Train:", train_df.shape)
print("Test:", test_df.shape)

display(train_df.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_3052/1735329471.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 train_df = pd.read_csv("/content/ag_news_train.csv")
#       4 test_df = pd.read_csv("/content/ag_news_test.csv")
#       5
#
# ...
